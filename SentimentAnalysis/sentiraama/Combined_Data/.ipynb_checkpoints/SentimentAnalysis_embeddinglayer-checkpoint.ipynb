# %%
import pandas as pd 
import numpy as np 
from sklearn.utils import shuffle

df = pd.DataFrame()
colnames=['Review','Sentiment'] 
df = pd.read_csv('combined_reviews.csv',encoding='utf-8',names=colnames)
df.set_index(['Review', 'Sentiment'])
df = shuffle(df).reset_index(drop=True)

X_train=df.loc[:550,'Review'].values
X_test=df.loc[551:,'Review'].values
Y_train=df.loc[:550,'Sentiment'].values
Y_test=df.loc[551:,'Sentiment'].values
df.head(10)
# print(X_train)
# Out:
#                                               Review  Sentiment
# 0  క్రైమ్ కామెడీ థ్రిల్లర్ గా తెరకెక్కు భలే మంచి ...          0
# 1  జియోనీ ఏ వన్ ఫోన్ డిస్ప్లే చాలా బాగుండు బాటరీ ...          1
# 2  హలో ఫ్రెండ్స్ జనవరి 28 2004 న ప్రకటించు D 70 క...          0
# 3  హలో ఫ్రెండ్ నేడు నేను వివో y 55 s మొబైల్ ఫోన్ ...          0
# 4  హే పీప్స్ ఈ ఫోన్ చాలా అధిక స్పెక్స్ ఉండు కానీ ...          0
# 5  ఈ పుస్తకం నేను యువ పాఠక ' ముందుకు సాగు ప్రారంభ...          1
# 6  కానన్ కు భారతదేశం DSLR మార్కెట్ చాలా బలమైన స్థ...          0
# 7  పారిజాతం ( నయనతార ) ఆత్మవిశ్వాసం ఆత్మాభిమానం ఎ...          0
# 8  యజ్ఞం తర్వాత గోపీచంద్ ఎయస్ రవికుమార్ చౌదరి దర్...          0
# 9  స్వీటీ అనే ముద్దు పేరున్న సౌందర్యం అనుష్క తాను...          1

# %%
from tensorflow.python.keras.preprocessing.text import Tokenizer
from tensorflow.python.keras.preprocessing.sequence import pad_sequences

tokenizer_obj = Tokenizer()
Total_Reviews = df.loc[:,'Review'].values
tokenizer_obj.fit_on_texts(Total_Reviews)

#pad sequence
max_length= max([len(s.split()) for s in Total_Reviews])

#size of the vocabulary
vocabulary_size = len(tokenizer_obj.word_index) +1 
X_train_tokens = tokenizer_obj.texts_to_sequences(X_train)
X_test_tokens = tokenizer_obj.texts_to_sequences(X_test)

X_train_pad = pad_sequences (X_train_tokens,maxlen=max_length,padding="post")
X_test_pad = pad_sequences (X_test_tokens,maxlen=max_length,padding="post")

Total_Reviews_tokens = tokenizer_obj.texts_to_sequences(X_train)
Total_reviews_pad = pad_sequences(Total_Reviews_tokens,maxlen=max_length,padding="post")

print(X_train_pad)
print(max_length)
# Out:
# [[ 950   37  289 ...    0    0    0]
#  [8963   96 1344 ...    0    0    0]
#  [ 612  369 8964 ...    0    0    0]
#  ...
#  [ 677 1585 2925 ...    0    0    0]
#  [  74    3  420 ...    0    0    0]
#  [  16    4   42 ...    0    0    0]]
# 1670

# %%
#traiing the word2vec model
from gensim.models import Word2Vec
from gensim.models import FastText
from gensim.test.utils import get_tmpfile
from gensim import scripts
from smart_open import open
import re
f = open("combined_reviews.txt","r")
data = f.read()

#sg defines if the parameter is skpgram or cbow
sentences_strings_ted = []
for line in data.split('\n'):
    m = re.match(r'^(?:(?P<precolon>[^:]{,20}):)?(?P<postcolon>.*)$', line)
    sentences_strings_ted.extend(sent for sent in m.groupdict()['postcolon'].split('.') if sent)

sentences_ted = []
for sent_str in sentences_strings_ted:
	tokens = sent_str.split()
	sentences_ted.append(tokens)

Embedding_size =100 #embedding_size is the size of the embedding vector.

path = get_tmpfile("word2vec.model")
w2v_model = Word2Vec(sentences = sentences_ted,size=100, sg=0,hs=1,window=5, min_count=1, workers=4)


#building the vocabulary
vocabulary_words = w2v_model.wv.vocab.keys()
vocabulary = { x:i  for x,i in enumerate(vocabulary_words)}

print(vocabulary)
print(len(vocabulary))

embeddings = 1 * np.random.randn(len(vocabulary_words) + 1,Embedding_size)
embeddings[0] = 0 

for index,word in vocabulary.items():
#     embeddings[index] = np.random.uniform(-0.25,0.25,Embedding_size)
    embeddings[index] = w2v_model.wv[word]
        
    
print(embeddings.shape)
print(embeddings)
# Out:
# {0: 'మధ్య', 1: 'తరగతి', 2: 'వాళ్ళకి', 3: 'ఉపయోగకరం', 4: 'కాని', 5: 'అందులో', 6: 'USB', 7: 'కనెక్షన్', 8: 'తేడా', 9: 'ఉండు', 10: '1', 11: 'కు', 12: 'కనెక్ట్', 13: 'అయ్యినప్పుడు', 14: 'అది', 15: 'స్పందిచలేదుUSB', 16: '2', 17: 'కి', 18: 'చెయ్యి', 19: 'tv', 20: 'అవ్వు', 21: 'ఎందుకంటే', 22: 'ఇది', 23: 'తారుమారుగా', 24: 'బడ్జెట్', 25: 'వినియోగదారుడు', 26: 'కోర', 27: 'మంచి', 28: 'స్పష్టత', 29: 'సౌండ్', 30: 'ధర', 31: 'డిజైన్', 32: 'మరియు', 33: 'ఫీచర్', 34: 'చాలామటుకు', 35: 'TVలు', 36: 'నలుపే', 37: 'అరుదుగా', 38: 'షైనీ', 39: 'సిల్వర్', 40: 'TVs', 41: 'సామ్సంగ్', 42: 'LG', 43: 'వారు', 44: 'హై', 45: 'ఎండ్', 46: 'మోడల్స్', 47: 'లోన', 48: 'Vu', 49: '4', 50: 'k', 51: '16', 52: 'a', 53: 'మోడల్', 54: 'యొక్క', 55: 'వెనుక', 56: 'ఇరు', 57: 'వైపులు', 58: 'సిల్వర్లో', 59: 'పెద్ద', 60: 'ఉపయోగం', 61: 'లేదు', 62: 'బేజల్', 63: 'కూడా', 64: 'స్లిమ్గా', 65: 'ముందు', 66: 'మొత్తం', 67: 'ప్యానలే', 68: 'ఆక్రమించు', 69: 'పిక్చర్', 70: 'పర్ఫొర్మన్సె', 71: 'మేము', 72: 'సరిగ్గా', 73: 'LEDN', 74: '50', 75: 'K', 76: '310', 77: 'X', 78: '3', 79: 'D', 80: 'ను', 81: 'సమీక్షించు', 82: 'అనేక', 83: 'రకం', 84: 'కంటెంట్లను', 85: 'ఉపయోగించు', 86: 'ఇందులో', 87: 'ప్రామాణికమైన', 88: 'నిర్వచనం', 89: '720', 90: 'p', 91: 'TV', 92: 'కార్యక్రమం', 93: 'వీడియో', 94: 'క్లిప్లు', 95: 'ఏద్జె', 96: 'ఒఫ్', 97: 'టుమొర్రౌ', 98: '1080', 99: 'వెర్షన్', 100: '-', 101: 'మెన్', 102: ':', 103: 'డెయ్స్', 104: 'ఫ్యుచర్', 105: 'పాస్ట', 106: 'స్టాక్', 107: 'ఫుటేజ్', 108: 'డెమో', 109: 'క్లిప్', 110: 'ఇంటర్నెట్', 111: 'మీడియా', 112: 'ప్రసారం', 113: 'ప్రదర్శన', 114: 'ఎలా', 115: 'చూడు', 116: 'వివిధం', 117: 'రెసొల్యుషన్స్', 118: 'లో', 119: 'YouTube', 120: 'రన్', 121: 'అంగుళం', 122: 'LED', 123: 'నుండి', 124: 'ఆడియో', 125: 'అవుట్పుట్', 126: 'అంత', 127: 'బాలేదు', 128: 'అని', 129: 'చెప్పు', 130: 'అలాగే', 131: 'బాగుండు', 132: 'ఈ', 133: 'చిన్న', 134: 'స్పీకర్', 135: 'ఉపయోగపడు', 136: 'ఆశించట్లేదు', 137: 'కానీ', 138: 'కొన్ని', 139: 'సమయం', 140: 'దాని', 141: 'పనితీరు', 142: 'నిరాశ', 143: 'గురయ్యాము', 144: 'వాల్యూమ్', 145: 'చాలా', 146: 'తక్కువ', 147: 'మీరు', 148: 'తగు', 149: 'పొందడానికివాల్యూమ్', 150: 'ఎక్కువ', 151: 'పెట్టు', 152: 'వస్తంది', 153: 'ఫ్రొస్', 154: 'సమగ్ర', 155: 'లిస్ట్', 156: 'అద్భుతమైన', 157: 'నాణ్యత', 158: 'UHD', 159: 'video', 160: 'సౌకర్యం', 161: 'పోర్ట్స్', 162: 'ఖోన్స్', 163: 'ఇంకా', 164: 'బాగుండచ్చు', 165: 'రంగు', 166: 'నిస్తేజం', 167: 'చెత్త', 168: 'రిమోట్', 169: 'యూజర్', 170: 'ఇంటర్ఫేస్రేటింగ్లు', 171: 'డిజైన్', 172: 'డబ్బు', 173: 'తగ్గ', 174: 'విలువ', 175: '5', 176: 'మీద', 177: 'నేను', 178: 'అనుభవం', 179: 'ధన్యవాదం', 180: 'సహజం', 181: 'అనుభూతి', 182: 'అందించు', 183: 'గొప్ప', 184: 'కారణం', 185: 'ఒక', 186: 'సినిమా', 187: 'హాల్', 188: 'కలుగు', 189: 'అన్ని', 190: 'విధం', 191: 'అందుబాటు', 192: 'ఇతర', 193: 'బ్రాండ్', 194: 'TVలతో', 195: 'పోలువు', 196: 'దీని', 197: 'వాస్తవం', 198: 'ఉత్తమమైనదిదాని', 199: 'స్టైలిష్', 200: 'కోసం', 201: 'అదనపు', 202: 'రెండు', 203: 'నెల', 204: 'క్రితం', 205: '40', 206: 'పూర్తి', 207: 'Hd', 208: 'కొనుగోలు', 209: 'నిజంగా', 210: 'మంచిదని', 211: 'సంతోషించు', 212: 'అద్భుతం', 213: 'పిక్సెల్', 214: 'ఉందినాకు', 215: 'TVని', 216: 'ఆనందం', 217: 'కంపెనీ', 218: 'సేవ', 219: 'తరువాత', 220: 'గంట', 221: 'ఇన్స్టలేషన్', 222: 'జరుగు', 223: 'కొనుగోలుదారు', 224: 'అందరు', 225: 'దీన్ని', 226: 'సిఫార్సు', 227: 'vu', 228: 'hd', 229: 'తప్పు', 230: 'తర్వాత', 231: 'గూగుల్', 232: 'వెతుకు', 233: 'న', 234: 'చౌకైన', 235: 'ఉత్తమ', 236: 'ఇంత', 237: 'led', 238: 'దొరకు', 239: "'", 240: 'కుటుంబం', 241: 'స్నేహిత', 242: 'నంబర్', 243: 'సంవత్సరం', 244: 'ఉత్పత్తి', 245: 'వాడుతున్నాను', 246: 'ఎప్పుడూ', 247: 'ఏసమస్య', 248: 'రాలేదు', 249: 'ఫోన్', 250: 'భార్య', 251: 'సభ్యుడు', 252: 'కొత్త', 253: 'వాటిలా', 254: 'పనిచెయ్యి', 255: 'ఫ్రిజ్', 256: 'లేదా', 257: 'పాత్', 258: 'అయినా', 259: 'పని', 260: 'ఇల్లు', 261: 'సెర్విస్', 262: 'ప్రోడక్ట్', 263: 'లోని', 264: 'ఏ', 265: 'దీనితో', 266: 'పోటీ', 267: 'కొను', 268: 'సందేహం', 269: 'లేకుండు', 270: 'ఎంపి', 271: 'క', 272: 'హెవీ', 273: 'డ్యూటీ', 274: 'వాడకం', 275: 'సమీక్ష', 276: 'రాయి', 277: 'బ్రహ్మచారిని', 278: 'మొదట', 279: 'CRT', 280: 'ఏళ్ళక్రితం', 281: 'ట్యూనర్గా', 282:  ...
# 23037
# (23038, 100)
# [[ 1.07556343e-01  5.58998942e-01 -1.05003917e+00 ...  1.50063619e-01
#    3.24184716e-01  1.84384644e+00]
#  [-7.52513260e-02 -2.25705355e-01  3.13416310e-02 ...  1.09186256e-02
#    1.07562028e-01  4.20404345e-01]
#  [-2.89466739e-01  2.77722180e-01 -3.17443818e-01 ...  2.63056070e-01
#   -8.13851506e-02  3.37087750e-01]
#  ...
#  [-2.12251972e-02  4.94211540e-02  1.82906189e-03 ...  2.17828304e-01
#   -3.99152637e-02  2.96941072e-01]
#  [ 2.40602821e-01  1.32777676e-01  3.11897397e-01 ...  5.00330552e-02
#    3.12255584e-02  2.58682370e-01]
#  [ 1.29419185e+00  7.87367772e-03  1.52024705e+00 ...  6.02946845e-02
#   -6.83858664e-02  2.14083752e-02]]

# %%
from keras.models import Sequential
from keras.layers import Dense,Embedding,LSTM,GRU
from keras.layers.embeddings import Embedding
from gensim.models import Word2Vec
from keras.regularizers import l2
from keras import optimizers

model=Sequential()
model.add(Embedding(len(embeddings), Embedding_size ,weights=[embeddings] ,input_length=max_length, trainable=True))
model.add(LSTM(units=75, dropout=0.2, recurrent_dropout=0.2, return_sequences=False))
model.add(Dense(64, activation='softmax'))
rmsprop = optimizers.RMSprop(learning_rate=0.001, rho=0.9)
model.compile(loss = 'sparse_categorical_crossentropy' , optimizer = rmsprop, metrics = ['accuracy'])

# %%
print("Training")

model.fit(X_train_pad,Y_train,epochs =10, batch_size =8, validation_data = (X_test_pad,Y_test),verbose=2)
# Out:
# Training
# Train on 551 samples, validate on 121 samples
# Epoch 1/10
#  - 42s - loss: 1.0300 - accuracy: 0.5245 - val_loss: 0.7129 - val_accuracy: 0.4793
# Epoch 2/10
#  - 42s - loss: 0.7202 - accuracy: 0.4610 - val_loss: 0.6940 - val_accuracy: 0.5207
# Epoch 3/10
#  - 41s - loss: 0.7169 - accuracy: 0.4791 - val_loss: 0.7038 - val_accuracy: 0.4793
# Epoch 4/10
#  - 40s - loss: 0.7083 - accuracy: 0.5064 - val_loss: 0.7001 - val_accuracy: 0.4793
# Epoch 5/10
#  - 46s - loss: 0.7101 - accuracy: 0.4791 - val_loss: 0.6972 - val_accuracy: 0.4793
# Epoch 6/10
#  - 43s - loss: 0.7009 - accuracy: 0.4955 - val_loss: 0.6976 - val_accuracy: 0.4793
# Epoch 7/10
#  - 44s - loss: 0.7044 - accuracy: 0.4973 - val_loss: 0.7017 - val_accuracy: 0.4793
# Epoch 8/10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-47e4143e00b8> in <module>
#       1 print("Training")
#       2
# ----> 3 model.fit(X_train_pad,Y_train,epochs =10, batch_size =8, validation_data = (X_test_pad,Y_test),verbose=2)
#
# ~/anaconda3/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# ~/anaconda3/lib/python3.7/site-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3290
#    3291     fetched = self._callable_fn(*array_vals,
# -> 3292                                 run_metadata=self.run_metadata)
#    3293     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3294     output_structure = nest.pack_sequence_as(
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
