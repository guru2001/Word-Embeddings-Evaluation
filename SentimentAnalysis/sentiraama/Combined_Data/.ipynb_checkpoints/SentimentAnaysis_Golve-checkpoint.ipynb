# %%
import pandas as pd 
import numpy as np 
from sklearn.utils import shuffle

df = pd.DataFrame()
colnames=['Review','Sentiment'] 
df = pd.read_csv('combined_reviews.csv',encoding='utf-8',names=colnames)
df.set_index(['Review', 'Sentiment'])
df = shuffle(df).reset_index(drop=True)

X_train=df.loc[:550,'Review'].values
X_test=df.loc[551:,'Review'].values
Y_train=df.loc[:550,'Sentiment'].values
Y_test=df.loc[551:,'Sentiment'].values
df.head(10)
# Out:
#                                               Review  Sentiment
# 0  హాయ్ గయ్స్ నేడు నేను మీరు నేను సామ్సంగ్ గెలాక్...          1
# 1  నేను నచ్చు -1 ది స్నాప్డ్రాగన్ 650 ప్రాసెసర్ మ...          1
# 2  సర్ధార్ గబ్బర్ సింగ్ పవర్ స్టార్ పవన్ కళ్యాణ్ ...          0
# 3  ' సామ్సంగ్ ' నేను కుటుంబం మరియు స్నేహిత కోసం న...          1
# 4  కార్తీక్ ( సత్యం కార్తీక్ ) చిన్నప్పట్నుంచి చద...          0
# 5  పారిజాతం ( నయనతార ) ఆత్మవిశ్వాసం ఆత్మాభిమానం ఎ...          0
# 6  భారతీయ గొప్ప రచయిత రవీంద్రనాథ్ ఠాగూర్ చే వ్రాయ...          1
# 7  శ్రీనివాస్ విస్సా నిర్మాత రామబ్రహ్మం సుంకర స్క...          1
# 8  కథః సప్తగిరి సప్తగిరికి నటన అంటే ప్రాణం పెద్ద ...          1
# 9  అల్లుడు శ్రీను సినిమా తర్వాత ప్రముఖం నిర్మాత బ...          0

# %%
from tensorflow.python.keras.preprocessing.text import Tokenizer
from tensorflow.python.keras.preprocessing.sequence import pad_sequences

tokenizer_obj = Tokenizer()
Total_Reviews = df.loc[:,'Review'].values
tokenizer_obj.fit_on_texts(Total_Reviews)

#pad sequence
max_length= max([len(s.split()) for s in Total_Reviews])

#size of the vocabulary
vocabulary_size = len(tokenizer_obj.word_index) +1 
X_train_tokens = tokenizer_obj.texts_to_sequences(X_train)
X_test_tokens = tokenizer_obj.texts_to_sequences(X_test)

X_train_pad = pad_sequences (X_train_tokens,maxlen=max_length,padding="post")
X_test_pad = pad_sequences (X_test_tokens,maxlen=max_length,padding="post")

Total_Reviews_tokens = tokenizer_obj.texts_to_sequences(X_train)
Total_reviews_pad = pad_sequences(Total_Reviews_tokens,maxlen=max_length,padding="post")

print(X_train_pad)
print(max_length)
# Out:
# [[ 1024  4863   992 ...     0     0     0]
#  [   16   261   600 ...     0     0     0]
#  [ 4871   921   273 ...     0     0     0]
#  ...
#  [  186   795   537 ...     0     0     0]
#  [20224  2825   657 ...     0     0     0]
#  [  623   372     4 ...     0     0     0]]
# 1670

# %%
import numpy as np

f1=open("senti_vectors_glove.txt")
lines=f1.readlines()
vocabulary_words = []
vectors=[]
vocabulary = { x:i  for x,i in enumerate(vocabulary_words)}
for line in lines :
    line = line[:-1]
    line = line.split(' ')
    vocabulary_words.append(line[0])
    vectors.append(line[1:])
    # print(len(line))



Embedding_size =200
vocabulary = { x:i  for x,i in enumerate(vocabulary_words)}
print(vocabulary)
print(len(vocabulary))

embeddings = 1 * np.random.randn(len(vocabulary_words) + 1,200)
embeddings[0] = 0 

for index,word in vocabulary.items():
    embeddings[index] = vectors[index]

print(embeddings.shape)
print(embeddings)
# Out:
# {0: 'సినిమా', 1: 'చెయ్యి', 2: 'ఉండు', 3: 'ఈ', 4: '’', 5: '‘', 6: 'కూడా', 7: '\u200c', 8: 'తాను', 9: 'కథ', 10: 'పాత్ర', 11: 'ఆ', 12: 'కానీ', 13: 'చాలా', 14: 'హీరో', 15: 'నేను', 16: 'చూడు', 17: 'సన్నివేశం', 18: 'వచ్చు', 19: 'గా', 20: 'అనిపించు', 21: 'లో', 22: 'ప్రేక్షకుడు', 23: 'చెప్పు', 24: 'అతడు', 25: 'ఓ', 26: '-', 27: 'మరియు', 28: 'ఇది', 29: 'ఒక', 30: 'కనిపించు', 31: 'ఐతే', 32: 'లేదు', 33: 'ఆమె', 34: 'విషయం', 35: 'దర్శకుడు', 36: '.', 37: 'మంచి', 38: 'కామెడీ', 39: 'సాగు', 40: 'కథనం', 41: 'చూపించు', 42: 'అవ్వు', 43: 'పుస్తకం', 44: 'అతను', 45: 'బాగా', 46: 'మాత్రం', 47: 'కొన్ని', 48: 'చివర', 49: 'హీరోయిన్', 50: 'అది', 51: 'పెద్ద', 52: 'పడు', 53: 'పాట', 54: 'ను', 55: 'బాగుండు', 56: 'గురించి', 57: 'కు', 58: 'కోసం', 59: 'ఇవ్వు', 60: 'ఎలా', 61: 'ఆకట్టుకో', 62: 'తర్వాత', 63: 'మీద', 64: 'అని', 65: 'నుంచి', 66: 'కొంచెం', 67: '(', 68: ')', 69: 'మధ్య', 70: 'అనే', 71: 'నటన', 72: 'కెమెరా', 73: 'తో', 74: 'నటించు', 75: 'పెట్టు', 76: 'ప్రయత్నం', 77: 'బాగానే', 78: 'అమ్మాయి', 79: 'ప్రేమ', 80: 'అన్న', 81: 'కాదు', 82: 'రెండు', 83: 'ఇలాంటి', 84: 'అంత', 85: 'చదువు', 86: 'విలన్', 87: 'ఇక', 88: 'చిత్రం', 89: 'మిగతా', 90: 'మీరు', 91: 'వరకు', 92: 'వారు', 93: 'నేపథ్యం', 94: 'వెళ్లు', 95: 'సంగీతం', 96: 'మనం', 97: 'నటీనటుడు', 98: 'వల్ల', 99: 'ఏ', 100: 'కలుగు', 101: 'పని', 102: 'తియ్యి', 103: 'మామూలు', 104: 'అనుకో', 105: 'తీసుకో', 106: 'ఆయన', 107: 'స్క్రీన్', 108: 'రొటీన్', 109: 'ఏది', 110: 'తెలుగు', 111: 'క్లైమాక్స్', 112: 'తండ్రి', 113: 'జీవితం', 114: 'ఇందులో', 115: 'ఏమీ', 116: 'ప్రతి', 117: 'లేకుండు', 118: 'మాట', 119: 'ప్రధాన', 120: 'వాళ్లు', 121: 'విశ్లేషణ', 122: 'మరీ', 123: 'ముందు', 124: 'సమయం', 125: 'అయితే', 126: 'ఎక్కువ', 127: 'కొత్త', 128: 'తక్కువ', 129: 'వెయ్యి', 130: 'స్థాయి', 131: 'నాణ్యత', 132: 'మాస్', 133: 'ఎంత', 134: 'ఓకు', 135: 'నడిపించు', 136: 'అద్భుతం', 137: 'అను', 138: 'పెళ్లి', 139: 'సీన్', 140: 'విలువ', 141: 'కలువు', 142: 'తెలియు', 143: 'లాంటి', 144: 'అందం', 145: 'తెర', 146: 'నిరాశ', 147: 'జరుగు', 148: 'అయినా', 149: 'ఏం', 150: 'తీరు', 151: 'సాంకేతిక', 152: 'ఫోన్', 153: 'ఫీలింగ్', 154: 'గొప్ప', 155: 'ఆసక్తి', 156: 'యొక్క', 157: 'తప్పు', 158: 'నవ్వించు', 159: 'మళ్లీ', 160: 'ప్లే', 161: 'అసలు', 162: 'చిన్న', 163: 'లవ్', 164: '!', 165: 'అంటే', 166: 'ఆసక్తికరం', 167: 'ప్రేమించు', 168: 'సమస్య', 169: 'కలిగించు', 170: 'ఇల్లు', 171: 'కాబట్టి', 172: 'మరి', 173: 'నిర్మాణం', 174: 'అలా', 175: 'ద్వితీయార్ధంలో', 176: 'అక్కడ', 177: 'తరహా', 178: 'ఛాయాగ్రహణం', 179: 'దాని', 180: 'పాటు', 181: 'గంట', 182: 'తెలుసుకో', 183: 'చోటు', 184: 'పర్వాలేదు', 185: 'వినోదం', 186: 'ఎవరు', 187: 'కొనుగోలు', 188: 'డబ్బు', 189: 'గత', 190: 'వుండు', 191: 'అందరు', 192: 'కొంత', 193: 'మూడు', 194: 'రాజ్', 195: 'లేవు', 196: 'ఇలా', 197: 'ఎలాంటి', 198: 'బ్యాక్', 199: 'తిరుగు', 200: 'తొలి', 201: 'మరో', 202: 'అయిపో', 203: 'అంతా', 204: 'ఇబ్బంది', 205: 'తాము', 206: 'రాయి', 207: 'రోజు', 208: 'కష్టం', 209: 'కమర్షియల్', 210: 'మొత్తం', 211: 'వర్గం', 212: 'ఉపయోగించు', 213: 'కారణం', 214: 'కి', 215: 'త', 216: '"', 217: 'తమిళ', 218: 'అవసరం', 219: 'క్యారెక్టర్', 220: 'నిలువు', 221: 'పరిస్థితి', 222: 'రచయిత', 223: 'కొత్తగా', 224: 'దాన్ని', 225: 'పాయింట్', 226: 'తగ్గట్లు', 227: 'ప్రత్యేకత', 228: 'మాత్రమే', 229: 'లేదా', 230: 'TV', 231: 'అంచనా', 232: 'ఆకర్షణ', 233: 'కొత్తదనం', 234: 'డైలాగులు', 235: 'ప్రయత్నించు', 236: '2', 237: 'అర్థం', 238: 'లేని', 239: 'స్కోర్', 240: 'ఎక్కడా', 241: 'పూర్తిగా', 242: 'మారు', 243: 'ఇంటర్వెల్', 244: 'కొట్టు', 245: 'ఎపిసోడ్', 246: 'పేరు', 247: 'పండించు', 248: 'బ్యాగ్రౌండ్', 249: 'ఆశించు', 250: 'ట్రాక్', 251: 'పూర్తి', 252: 'అందించు', 253: 'కుటుంబం', 254: 'యాక్షన్', 255: 'ని', 256: 'నుండి', 257: 'ముద్ర', 258: 'మెప్పించు', 259: 'స్టోరీ', 260: 'పరిచయం', 261: 'మరింత', 262: 'నడువు', 263: 'ఫ్లాష్', 264: 'అక్కడక్కడ', 265: 'అలాంటి', 266: 'ధర', 267: 'నచ్చు', 268: 'నిజంగా', 269: 'మొదలవ్వు', 270: 'అతణ్ని', 271: 'ఇక్కడ', 272: 'కుర్రాడు', 273: 'డైరెక్టర్', 274: 'దీం', 275: 'పో', 276: 'మైనస్', 277: 'మొదట', 278: 'తప్ప', 279: 'పట్టు', 280: 'పరం', 281: 'సింగ్', 282: 'కొడుకు', 283: 'దీని', 284: 'సంబంధించు', 285: 'ఎమోషనల్', 286: 'ఒకటి', 287: 'ద్వారా', 288: 'ఎంచు', 289: 'భిన్నం', 290: 'కంటే ...
# 23044
# (23045, 200)
# [[ 0.520842    0.111163    0.071909   ... -0.023802   -1.173797
#   -0.61946   ]
#  [ 0.677066   -0.402405    0.078137   ... -0.111409   -0.835864
#   -0.801101  ]
#  [ 0.708731   -0.362224    0.366078   ... -0.122402   -0.952384
#   -0.761053  ]
#  ...
#  [-0.047337    0.019088   -0.015664   ...  0.005965    0.052134
#    0.045866  ]
#  [-0.022346    0.01056    -0.007052   ...  0.003984    0.025883
#    0.02402   ]
#  [-1.46062978  1.23555366 -0.1463338  ... -0.41729116  0.0857548
#    1.29075068]]

# %%
from keras.models import Sequential
from keras.layers import Dense,Embedding,LSTM,GRU
from keras.layers.embeddings import Embedding
from gensim.models import Word2Vec
from keras.regularizers import l2
from keras import optimizers

model=Sequential()
model.add(Embedding(len(embeddings), Embedding_size ,weights=[embeddings] ,input_length=max_length, trainable=True))
model.add(LSTM(units=75, dropout=0.2, recurrent_dropout=0.2, return_sequences=False))
model.add(Dense(64, activation='softmax'))
rmsprop = optimizers.RMSprop(learning_rate=0.001, rho=0.9)
model.compile(loss = 'sparse_categorical_crossentropy' , optimizer =rmsprop, metrics = ['accuracy'])
# Out:
# Using TensorFlow backend.

# %%
print("Training")

model.fit(X_train_pad,Y_train,epochs =10, batch_size =8, validation_data = (X_test_pad,Y_test),verbose=2)
# Out:
# Training
# WARNING:tensorflow:From /home/dama-sravani/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 551 samples, validate on 121 samples
# Epoch 1/10
#  - 91s - loss: 1.7802 - accuracy: 0.4955 - val_loss: 0.8577 - val_accuracy: 0.5620
# Epoch 2/10
#  - 90s - loss: 0.8060 - accuracy: 0.5082 - val_loss: 0.7847 - val_accuracy: 0.4380
# Epoch 3/10
#  - 94s - loss: 0.7490 - accuracy: 0.5027 - val_loss: 0.7631 - val_accuracy: 0.4380
# Epoch 4/10
#  - 89s - loss: 0.7274 - accuracy: 0.5045 - val_loss: 0.7289 - val_accuracy: 0.4380
# Epoch 5/10
#  - 87s - loss: 0.7220 - accuracy: 0.4991 - val_loss: 0.7313 - val_accuracy: 0.4380
# Epoch 6/10
#  - 92s - loss: 0.7199 - accuracy: 0.4882 - val_loss: 0.7063 - val_accuracy: 0.4380
# Epoch 7/10
#  - 79s - loss: 0.7147 - accuracy: 0.4809 - val_loss: 0.7582 - val_accuracy: 0.4380
# Epoch 8/10
#  - 86s - loss: 0.7136 - accuracy: 0.4955 - val_loss: 0.6941 - val_accuracy: 0.5620
# Epoch 9/10
#  - 88s - loss: 0.7119 - accuracy: 0.4936 - val_loss: 0.7007 - val_accuracy: 0.5620
# Epoch 10/10
#  - 88s - loss: 0.7052 - accuracy: 0.5535 - val_loss: 0.7246 - val_accuracy: 0.4380
